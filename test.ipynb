# %%
from lib.bigquery import BigQueryClient

project_id = "locomotive-ga4-data"
credentials_file = "credentials/service.json"
dataset_id = "analytics_303605385"

bq = BigQueryClient(credentials_file, project_id)

df = bq.run_query("events", dataset_id)

# %%
df.head()
# Out:
#    event_date     event_name                  event_timestamp  \
# 0  2022-11-22  session_start 2022-11-22 05:06:57.726015+00:00
# 1  2022-11-22      page_view 2022-11-22 05:06:57.726015+00:00
# 2  2022-11-22      page_view 2022-11-22 05:07:19.824554+00:00
# 3  2022-11-22  session_start 2022-11-22 05:07:19.824554+00:00
# 4  2022-11-22  session_start 2022-11-22 05:08:51.794449+00:00
#
#           user_pseudo_id       user_first_touch_timestamp  geo_region  \
# 0   832149188.1669093618 2022-11-22 05:06:57.726015+00:00  California
# 1   832149188.1669093618 2022-11-22 05:06:57.726015+00:00  California
# 2  1018364932.1669093640 2022-11-22 05:07:19.824554+00:00     Arizona
# 3  1018364932.1669093640 2022-11-22 05:07:19.824554+00:00     Arizona
# 4  2130374568.1669093731 2022-11-22 05:08:51.794449+00:00     Alberta
#
#       geo_city    channel  ga_session_id  ga_session_number  session_engaged  \
# 0  Los Angeles   (direct)     1669093617                  1             <NA>
# ...
